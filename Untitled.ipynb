# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Parsing the variants.csv file for all C321 clones

# %%
data = pd.read_csv("variants_smallfilesize.csv",dtype = {'UID': str, 'ALT': str, 'EXPERIMENT_SAMPLE_LABEL': str, 'REF': str, 'IS_HET': str, 'AO': str, 'QA': str} )
data.sort_values(by='EXPERIMENT_SAMPLE_LABEL')
data
# Out:
#              UID  POSITION            REF            ALT  \
# 0       d8d85551     15600       CGGGGGGA            NaN
# 1       b9e83de9    258675              C              G
# 2       abde5bf7    271150              A            NaN
# 3       840b02b7   1050277              G              A
# 4       7bb6e761   1050285              A              C
# 5       e7f6367c   1050297           TCAC            TGG
# 6       044b0adb   1050308  CGTGGTGATATGG  GGTCGTGGTATAA
# 7       964cb9f8   1097484              C            NaN
# 8       4ab38da0   1651288              G              A
# 9       40ba27db   1979270              C              A
# 10      124d2424   2067156              A            NaN
# 11      1ccb6c27   2170359              T            NaN
# 12      f1e83e33   2304688              A            NaN
# 13      0d3d1b8c   2515406      TCCCCCCCA       TCCCCCCA
# 14      da71e2ea   3424764              T            NaN
# 15      c52008c5   3424771              T            NaN
# 16      bfef19af   3666752              A            NaN
# 17      0cdb379e   4037695              G            NaN
# 18      91d1788a   4296227              G            NaN
# 19      19fc57f6    227192              A              G
# 20      cec57ad6    257928              G            NaN
# 21      854ef8df    257930              T              C
# 22      a7cbfdfc    810359              A              C
# 23      ad2518a7   1286793           AAGT           GAGC
# 24      02b7ef3b   1286805             GG             AA
# 25      b5381553   1286831              T              A
# 26      e599e907   1397035              G              C
# 27      5afc27aa   1397055              C              T
# 28      0f748052   1428000            CGG            NaN
# 29      5b1cb5f1   1428097              A              C
# ...          ...       ...            ...            ...
# 315122  43133753    226546              A            NaN
# 315123  24c7fbec    257908              G            NaN
# 315124  cec57ad6    257928              G            NaN
# 315125  854ef8df    257930              T            NaN
# 315126  e300fd56    807975      CAAAAAAAT            NaN
# 315127  64180070    808002              C            NaN
# 315128  56da932a    808143              T            NaN
# 315129  4fab92ea    808157              C            NaN
# 315130  c9162121    808163           AATG            NaN
# 315131  89765088    808175              T            NaN
# 315132  270adcc2    809048              C            NaN
# 315133  bdc70bd5   1265675              T            NaN
# 315134  16e8cd96   1266086              C            NaN
# 315135  fadc3d66   1300693              C            NaN
# 315136  0f748052   1428000            CGG            NaN
# 315137  fbcbccc1   1428052              T            NaN
# 315138  5b1cb5f1   1428097              A            NaN
# 315139  e67740ee   1428109              C            NaN
# 315140  0c6a878e   1978503              G            NaN
# 315141  88c1f2cd   1978516            ACT            NaN
# 315142  f1eb7f9e   2614612           CCTC            NaN
# 315143  f33458cc   2730486       ACCCCCCT            NaN
# 315144  c52008c5   3424771              T            NaN
# 315145  0a45186f   3764162              A            NaN
# 315146  e65f3913   3764179              A            NaN
# 315147  f02f4214   4040044              G            NaN
# 315148  3c075b22   4040436              G            NaN
# 315149  b6245ebd   4040448            ATT            NaN
# 315150  91d1788a   4296227              G            NaN
# 315151  872c3472   4507806              A            NaN
#
#        EXPERIMENT_SAMPLE_LABEL  INFO_DP  INFO_PAIREDR  INFO_PQR  INFO_MQMR  \
# 0                       C-A4-1      275      1.000000   319.500    39.7802
# 1                       C-A4-1       49      0.000000     0.000     0.0000
# 2                       C-A4-1      159      1.000000     0.000    39.6903
# 3                       C-A4-1      424      1.000000     0.000    39.5286
# 4                       C-A4-1      508      1.000000     0.000    39.6586
# 5                       C-A4-1      494      1.000000  1280.000    39.7009
# 6                       C-A4-1      565      1.000000  6628.000    39.7359
# 7                       C-A4-1      709      0.997143     0.000    48.1286
# 8                       C-A4-1      122      1.000000     0.000    39.8750
# 9                       C-A4-1      190      1.000000     0.000    39.0000
# 10                      C-A4-1     1150      1.000000     0.000    39.8731
# 11                      C-A4-1      373      1.000000     0.000    40.0000
# 12                      C-A4-1      837      1.000000     0.000    45.4209
# 13                      C-A4-1      223      1.000000   335.333    39.9573
# 14                      C-A4-1      327      1.000000     0.000    39.8708
# 15                      C-A4-1      306      1.000000     0.000    39.8618
# 16                      C-A4-1      300      1.000000     0.000    40.5320
# 17                      C-A4-1      268      1.000000     0.000    37.5338
# 18                      C-A4-1       30      1.000000     0.000    40.9286
# 19                      C-A4-1      283      1.000000     0.000    40.0000
# 20                      C-A4-1        4      1.000000     0.000    40.0000
# 21                      C-A4-1        4      1.000000     0.000    33.0000
# 22                      C-A4-1      231      0.962963     0.000    60.0000
# 23                      C-A4-1     1670      0.996819  1597.000    57.1209
# 24                      C-A4-1     1518      0.995816     0.000    57.4414
# 25                      C-A4-1     1718      0.995541     0.000    58.8439
# 26                      C-A4-1      336      1.000000     0.000    39.9669
# 27                      C-A4-1      396      1.000000     0.000    39.9235
# 28                      C-A4-1     1101      0.988139   112.000    59.0949
# 29                      C-A4-1     1133      0.993327     0.000    50.0553
# ...                        ...      ...           ...       ...        ...
# 315122                  F-H5-2     1024      1.000000     0.000    40.0795
# 315123                  F-H5-2       21      0.800000     0.000    37.2000
# 315124                  F-H5-2        4      1.000000     0.000    40.0000
# 315125                  F-H5-2        4      1.000000     0.000    33.0000
# 315126                  F-H5-2       71      0.985075    92.000    60.0000
# 315127                  F-H5-2       67      0.984615     0.000    60.0000
# 315128                  F-H5-2       64      0.967213     0.000    60.0000
# 315129                  F-H5-2       62      0.966667     0.000    59.5333
# 315130                  F-H5-2       58      0.982143     0.000    60.0000
# 315131                  F-H5-2       60      0.982759     0.000    60.0000
# 315132                  F-H5-2       44      1.000000     0.000    60.0000
# 315133                  F-H5-2     1315      0.990084     0.000    59.9436
# 315134                  F-H5-2     1614      0.992131     0.000    59.9311
# 315135                  F-H5-2       32      0.000000     0.000     0.0000
# 315136                  F-H5-2     1101      0.988139   112.000    59.0949
# 315137                  F-H5-2     1149      0.986842     0.000    56.6140
# 315138                  F-H5-2     1133      0.993327     0.000    50.0553
# 315139                  F-H5-2     1067      0.993902     0.000    47.4705
# 315140                  F-H5-2       18      1.000000     0.000    40.0000
# 315141                  F-H5-2        2      0.000000     0.000     0.0000
# 315142                  F-H5-2     2518      0.989516  1891.000    59.9234
# 315143                  F-H5-2       12      1.000000    16.500    40.0000
# 315144                  F-H5-2      306      1.000000     0.000    39.8618
# 315145                  F-H5-2      297      1.000000     0.000    42.0678
# 315146                  F-H5-2      163      1.000000     0.000    41.8375
# 315147                  F-H5-2        2      0.000000     0.000     0.0000
# 315148                  F-H5-2       99      1.000000     0.000    39.9897
# 315149                  F-H5-2      102      1.000000    21.000    39.9798
# 315150                  F-H5-2       30      1.000000     0.000    40.9286
# 315151                  F-H5-2       64      1.000000     0.000    39.4242
#
#         INFO_AN      ...        INFO_RPL  INFO_EFF_GT   INFO_AF  \
# 0           156      ...             NaN          NaN       NaN
# 1            74      ...               0            1  1.000000
# 2           136      ...             NaN          NaN       NaN
# 3           170      ...              71            1  0.617647
# 4           172      ...              80            1  0.610465
# 5           164      ...              29            1  0.591463
# 6           166      ...              31            1  0.590361
# 7           170      ...             NaN          NaN       NaN
# 8           112      ...              23            1  0.642857
# 9           150      ...               0            1  0.993333
# 10          174      ...             NaN          NaN       NaN
# 11          160      ...             NaN          NaN       NaN
# 12          174      ...             NaN          NaN       NaN
# 13          150      ...               0            2  0.040000
# 14          160      ...             NaN          NaN       NaN
# 15          158      ...             NaN          NaN       NaN
# 16          160      ...             NaN          NaN       NaN
# 17          156      ...             NaN          NaN       NaN
# 18           40      ...             NaN          NaN       NaN
# 19          160      ...              67            1  0.312500
# 20            4      ...             NaN          NaN       NaN
# 21            4      ...               2            1  0.500000
# 22          148      ...               0            1  0.972973
# 23          172      ...             701            1  0.633721
# 24          172      ...             515            1  0.633721
# 25          174      ...             260            1  0.637931
# 26          162      ...               0            1  0.024691
# 27          166      ...               0            1  0.024096
# 28           92      ...             NaN          NaN       NaN
# 29          148      ...               5            1  0.581081
# ...         ...      ...             ...          ...       ...
# 315122      116      ...             NaN          NaN       NaN
# 315123       32      ...             NaN          NaN       NaN
# 315124        4      ...             NaN          NaN       NaN
# 315125        4      ...             NaN          NaN       NaN
# 315126       12      ...             NaN          NaN       NaN
# 315127       10      ...             NaN          NaN       NaN
# 315128        8      ...             NaN          NaN       NaN
# 315129        8      ...             NaN          NaN       NaN
# 315130        6      ...             NaN          NaN       NaN
# 315131        6      ...             NaN          NaN       NaN
# 315132        6      ...             NaN          NaN       NaN
# 315133       64      ...             NaN          NaN       NaN
# 315134      156      ...             NaN          NaN       NaN
# 315135       52      ...             NaN          NaN       NaN
# 315136       92      ...             NaN          NaN       NaN
# 315137       74      ...             NaN          NaN       NaN
# 315138      148      ...             NaN          NaN       NaN
# 315139      160      ...             NaN          NaN       NaN
# 315140       32      ...             NaN          NaN       NaN
# 315141        2      ...             NaN          NaN       NaN
# 315142      162      ...             NaN          NaN       NaN
# 315143       20      ...             NaN          NaN       NaN
# 315144      158      ...             NaN          NaN       NaN
# 315145       60      ...             NaN          NaN       NaN
# 315146       58      ...             NaN          NaN       NaN
# 315147        2      ...             NaN          NaN       NaN
# 315148       64      ...             NaN          NaN       NaN
# 315149       66      ...             NaN          NaN       NaN
# 315150       40      ...             NaN          NaN       NaN
# 315151       78      ...             NaN          NaN       NaN
#
#         INFO_EFF_CLASS  INFO_MEANALT  INFO_EFF_RANK  INFO_EFF_CODING  \
# 0                  NaN           NaN            NaN              NaN
# 1                  NaN       1.00000              1       NON_CODING
# 2                  NaN           NaN            NaN              NaN
# 3             MISSENSE       1.00000              1           CODING
# 4             MISSENSE       1.00000              1           CODING
# 5                  NaN       1.00000              1           CODING
# 6                  NaN       1.04000            NaN           CODING
# 7                  NaN           NaN            NaN              NaN
# 8                  NaN       1.00000              1       NON_CODING
# 9                  NaN       1.00000            NaN              NaN
# 10                 NaN           NaN            NaN              NaN
# 11                 NaN           NaN            NaN              NaN
# 12                 NaN           NaN            NaN              NaN
# 13                 NaN       1.00000              1           CODING
# 14                 NaN           NaN            NaN              NaN
# 15                 NaN           NaN            NaN              NaN
# 16                 NaN           NaN            NaN              NaN
# 17                 NaN           NaN            NaN              NaN
# 18                 NaN           NaN            NaN              NaN
# 19                 NaN       1.00000            NaN              NaN
# 20                 NaN           NaN            NaN              NaN
# 21                 NaN       1.00000              1       NON_CODING
# 22            MISSENSE       1.00000              1           CODING
# 23                 NaN       1.03636            NaN              NaN
# 24                 NaN       1.05455            NaN              NaN
# 25                 NaN       1.00000            NaN              NaN
# 26              SILENT       1.00000              1           CODING
# 27            MISSENSE       1.00000              1           CODING
# 28                 NaN           NaN            NaN              NaN
# 29                 NaN       1.00000              1       NON_CODING
# ...                ...           ...            ...              ...
# 315122             NaN           NaN            NaN              NaN
# 315123             NaN           NaN            NaN              NaN
# 315124             NaN           NaN            NaN              NaN
# 315125             NaN           NaN            NaN              NaN
# 315126             NaN           NaN            NaN              NaN
# 315127             NaN           NaN            NaN              NaN
# 315128             NaN           NaN            NaN              NaN
# 315129             NaN           NaN            NaN              NaN
# 315130             NaN           NaN            NaN              NaN
# 315131             NaN           NaN            NaN              NaN
# 315132             NaN           NaN            NaN              NaN
# 315133             NaN           NaN            NaN              NaN
# 315134             NaN           NaN            NaN              NaN
# 315135             NaN           NaN            NaN              NaN
# 315136             NaN           NaN            NaN              NaN
# 315137             NaN           NaN            NaN              NaN
# 315138             NaN           NaN            NaN              NaN
# 315139             NaN           NaN            NaN              NaN
# 315140             NaN           NaN            NaN              NaN
# 315141             NaN           NaN            NaN              NaN
# 315142             NaN           NaN            NaN              NaN
# 315143             NaN           NaN            NaN              NaN
# 315144             NaN           NaN            NaN              NaN
# 315145             NaN           NaN            NaN              NaN
# 315146             NaN           NaN            NaN              NaN
# 315147             NaN           NaN            NaN              NaN
# 315148             NaN           NaN            NaN              NaN
# 315149             NaN           NaN            NaN              NaN
# 315150             NaN           NaN            NaN              NaN
# 315151             NaN           NaN            NaN              NaN
#
#         INFO_EFF_TR  INFO_EFF_GENE          ALT.1
# 0               NaN            NaN            NaN
# 1             b0240            crl              G
# 2               NaN            NaN            NaN
# 3             b0988          insB1              A
# 4             b0988          insB1              C
# 5             b0988          insB1            TGG
# 6             b0988          insB1  GGTCGTGGTATAA
# 7               NaN            NaN            NaN
# 8             b1578          insD1              A
# 9               NaN            NaN              A
# 10              NaN            NaN            NaN
# 11              NaN            NaN            NaN
# 12              NaN            NaN            NaN
# 13            b2394          insL1       TCCCCCCA
# 14              NaN            NaN            NaN
# 15              NaN            NaN            NaN
# 16              NaN            NaN            NaN
# 17              NaN            NaN            NaN
# 18              NaN            NaN            NaN
# 19              NaN            NaN              G
# 20              NaN            NaN            NaN
# 21            b0240            crl              C
# 22            b0775           bioB              C
# 23              NaN            NaN           GAGC
# 24              NaN            NaN             AA
# 25              NaN            NaN              A
# 26            b1331          insH1              C
# 27            b1331          insH1              T
# 28              NaN            NaN            NaN
# 29            b4570           lomR              C
# ...             ...            ...            ...
# 315122          NaN            NaN            NaN
# 315123          NaN            NaN            NaN
# 315124          NaN            NaN            NaN
# 315125          NaN            NaN            NaN
# 315126          NaN            NaN            NaN
# 315127          NaN            NaN            NaN
# 315128          NaN            NaN            NaN
# 315129          NaN            NaN            NaN
# 315130          NaN            NaN            NaN
# 315131          NaN            NaN            NaN
# 315132          NaN            NaN            NaN
# 315133          NaN            NaN            NaN
# 315134          NaN            NaN            NaN
# 315135          NaN            NaN            NaN
# 315136          NaN            NaN            NaN
# 315137          NaN            NaN            NaN
# 315138          NaN            NaN            NaN
# 315139          NaN            NaN            NaN
# 315140          NaN            NaN            NaN
# 315141          NaN            NaN            NaN
# 315142          NaN            NaN            NaN
# 315143          NaN            NaN            NaN
# 315144          NaN            NaN            NaN
# 315145          NaN            NaN            NaN
# 315146          NaN            NaN            NaN
# 315147          NaN            NaN            NaN
# 315148          NaN            NaN            NaN
# 315149          NaN            NaN            NaN
# 315150          NaN            NaN            NaN
# 315151          NaN            NaN            NaN
#
# [315152 rows x 68 columns]

# %% [markdown]
# Figure out a bit of stuff about the variant set....looking for numbers of certain types of variants, read depth, etc.
#
# Instance 1: Number of variant calls with read depth < min_read_depth
# Instance 2: Number of variant calls with allele fracgion < min_allele_fraction

# %%
min_read_depth = 10
min_allele_fraction = 0.7
variants = data[data.ALT.notnull()]
print("total variant calls: ",variants.UID.count())
print("variant calls under min read depth: ",variants[variants.DP < min_read_depth].UID.count())
print("variant calls under min allele fraction: ",variants[variants.AF < min_allele_fraction].UID.count())
# Out:
# total variant calls:  47262
# variant calls under min read depth:  1926
# variant calls under min allele fraction:  1814

# %% [markdown]
# Begin to cull the data.
#
# Remove everything without a minimal read depth or allele fraction

# %%
vc = variants[variants.DP > min_read_depth]
vc = vc[vc.AF > min_allele_fraction]
print("total culled variant calls: ",vc.UID.count())
# Out:
# total culled variant calls:  43678

# %% [markdown]
# Separate the culled variant calls into ECNR2.1, C321.∆A, and C321.∆A_F11 bins

# %%
Evc = vc[vc.EXPERIMENT_SAMPLE_LABEL.str[0] == 'E']
Cvc = vc[vc.EXPERIMENT_SAMPLE_LABEL.str[0] == 'C']
Fvc = vc[vc.EXPERIMENT_SAMPLE_LABEL.str[0] == 'F']
print("total ENCR2.1 culled variant calls: ",Evc.UID.count())
print("total C321.∆A culled variant calls: ",Cvc.UID.count())
print("total C321.∆A_F11 culled variant calls: ",Fvc.UID.count())
# Out:
# total ENCR2.1 culled variant calls:  2002
# total C321.∆A culled variant calls:  19658
# total C321.∆A_F11 culled variant calls:  22018
